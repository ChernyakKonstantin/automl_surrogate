# %%
import openml
from sklearn.model_selection import KFold
import numpy as np
import argparse
import os

# %%
# Out:
# /Users/cherniak/anaconda3/envs/GAMLET/lib/python3.10/site-packages/openml/datasets/functions.py:438: FutureWarning: Starting from Version 0.15 `download_data`, `download_qualities`, and `download_features_meta_data` will all be ``False`` instead of ``True`` by default to enable lazy loading. To disable this message until version 0.15 explicitly set `download_data`, `download_qualities`, and `download_features_meta_data` to a bool while calling `get_dataset`.
#   warnings.warn(

# %%
x_ = x.to_numpy()
x_[train_index].shape
# Out:
# (4877, 1636)

# %%
# Out:
# 0 4876 542
# 1 4876 542
# 2 4876 542
# 3 4876 542
# 4 4876 542
# 5 4876 542
# 6 4876 542
# 7 4876 542
# 8 4877 541
# 9 4877 541

# %%
train_index
# Out:
# array([   0,    1,    2, ..., 5415, 5416, 5417])

# %%
test_index
# Out:
# array([  14,   15,   20,   42,   52,   63,   70,   71,   96,  105,  109,
#         143,  144,  145,  150,  152,  153,  155,  174,  183,  213,  235,
#         243,  252,  253,  269,  271,  296,  312,  317,  319,  327,  333,
#         334,  373,  377,  378,  379,  391,  402,  405,  410,  412,  417,
#         423,  431,  450,  454,  461,  467,  475,  489,  497,  505,  519,
#         542,  562,  565,  591,  601,  606,  609,  617,  624,  626,  637,
#         648,  652,  658,  668,  677,  690,  696,  704,  715,  721,  728,
#         732,  738,  753,  803,  806,  811,  814,  818,  832,  837,  838,
#         843,  869,  873,  878,  884,  886,  889,  897,  903,  905,  907,
#         915,  928,  939,  944,  956,  967, 1018, 1031, 1033, 1046, 1052,
#        1067, 1088, 1095, 1106, 1110, 1111, 1133, 1137, 1150, 1174, 1182,
#        1187, 1191, 1200, 1202, 1207, 1214, 1251, 1254, 1295, 1303, 1306,
#        1311, 1312, 1324, 1337, 1345, 1350, 1360, 1368, 1372, 1389, 1423,
# ...
